# %% [markdown]
# <a href="https://colab.research.google.com/github/Abkhenaten/Projects/blob/master/GITHUB_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Start using request library
import requests

# %%
#To pass the three parameters, we put them in the dictionary query. We can put together the full URL from the base URL and the path.
query = {'q': 'tetris+language:assembly', 'sort': 'stars', 'order': 'desc'}
url = 'https://api.github.com/search/repositories'

# %%
#Since everything is in place, we can make the actual call.
response = requests.get(url, params=query)

# %%
#What status code did we get from the request
response.status_code
# Out:
# 200

# %%
#Or we check if ok is True
response.ok
# Out:
# True

# %%
#What does the response data looks like
data = response.json()
data
# Out:
# {'incomplete_results': False,
#  'items': [{'archive_url': 'https://api.github.com/repos/daniel-e/tetros/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/daniel-e/tetros/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/daniel-e/tetros/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/daniel-e/tetros/branches{/branch}',
#    'clone_url': 'https://github.com/daniel-e/tetros.git',
#    'collaborators_url': 'https://api.github.com/repos/daniel-e/tetros/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/daniel-e/tetros/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/daniel-e/tetros/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/daniel-e/tetros/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/daniel-e/tetros/contents/{+path}',
# ...

# %%
#List all the keys in the dictionary
print(data.keys())
# Out:
# dict_keys(['total_count', 'incomplete_results', 'items'])

# %%
#What is the value of the total count
print(f'Total number of repositories matching quesry is {data["total_count"]}')
# Out:
# Total number of repositories matching quesry is 339

# %%
#How many items in the items array
print(f'The length of the items array is {len(data["items"])}')
# Out:
# The length of the items array is 30

# %%
#get the first item from the array
item1 = data['items'][0]

# %%
#What are the keys of the item
print(item1.keys())
# Out:
# dict_keys(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url', 'description', 'fork', 'url', 'forks_url', 'keys_url', 'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url', 'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url', 'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url', 'languages_url', 'stargazers_url', 'contributors_url', 'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url', 'comments_url', 'issue_comment_url', 'contents_url', 'compare_url', 'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url', 'milestones_url', 'notifications_url', 'labels_url', 'releases_url', 'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url', 'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size', 'stargazers_count', 'watchers_count', 'language', 'has_issues', 'has_projects', 'has_downloads', 'has_wiki', 'has_pages', 'forks_count', 'mirror_url', 'archived', 'disabled', 'open_issues_count', 'l
# ...

# %%
#How a failed request behaves. Just break url
broken_url = 'http://api.github.com/this_is_broken'
broken_response = requests.get(broken_url)
print(broken_response.ok)
print(broken_response.status_code)
# Out:
# False
# 404

# %%
#Json message of the broken code
some_data = broken_response.json()
some_data
# Out:
# {'documentation_url': 'https://docs.github.com/rest', 'message': 'Not Found'}
